# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
np.random.seed(19680801)

# %%
hd = pd.read_excel('C:/Users/DELL/HOUSEDAT.xlsx')
hd.head()
# Out:
#     PRICE  SQFT  BEDROOMS  BATHS  AGE  OCCUPANCY  POOL  STYLE  FIREPLACE  \
# 0   66500   741         1      1   18          1     1      1          1
# 1   66000   741         1      1   18          2     1      1          0
# 2   68500   790         1      1   18          1     0      1          1
# 3  102000  2783         2      2   18          1     0      1          1
# 4   54000  1165         2      1   35          2     0      1          0
#
#    WATERFRONT  DOM
# 0           0    6
# 1           0   23
# 2           0    8
# 3           0   50
# 4           0  190

# %%
hd.corr()
# Out:
#                PRICE      SQFT  BEDROOMS     BATHS       AGE  OCCUPANCY  \
# PRICE       1.000000  0.760689  0.455189  0.645341 -0.208609  -0.206716
# SQFT        0.760689  1.000000  0.684591  0.716111 -0.138031  -0.308667
# BEDROOMS    0.455189  0.684591  1.000000  0.578808 -0.168075  -0.225346
# BATHS       0.645341  0.716111  0.578808  1.000000 -0.293107  -0.284255
# AGE        -0.208609 -0.138031 -0.168075 -0.293107  1.000000  -0.011167
# OCCUPANCY  -0.206716 -0.308667 -0.225346 -0.284255 -0.011167   1.000000
# POOL        0.202269  0.256155  0.137703  0.202991  0.009081  -0.095383
# STYLE       0.149208  0.126682  0.037503  0.108446 -0.016037  -0.100704
# FIREPLACE   0.310626  0.374238  0.210015  0.364095 -0.209634  -0.327940
# WATERFRONT  0.309940  0.214929  0.085691  0.222732 -0.165418  -0.048484
# DOM         0.078929  0.104335  0.089487  0.074509 -0.064640   0.070802
#
#                 POOL     STYLE  FIREPLACE  WATERFRONT       DOM
# ...

# %%
import statsmodels.api as sm

# %%
y = hd['PRICE']
x = hd[['SQFT', 'BEDROOMS', 'BATHS']]

# %%
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     568.3
# Date:                Thu, 30 May 2024   Prob (F-statistic):          2.87e-221
# Time:                        11:17:23   Log-Likelihood:                -13676.
# No. Observations:                1080   AIC:                         2.736e+04
# Df Residuals:                    1076   BIC:                         2.738e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.841e+04   1.16e+04     -4.181      0.000   -7.11e+04   -2.57e+04
# ...

# %%
x = hd[['SQFT', 'BEDROOMS', 'BATHS','POOL', 'FIREPLACE', 'WATERFRONT']]

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     302.7
# Date:                Thu, 30 May 2024   Prob (F-statistic):          8.82e-227
# Time:                        10:27:01   Log-Likelihood:                -13654.
# No. Observations:                1080   AIC:                         2.732e+04
# Df Residuals:                    1073   BIC:                         2.736e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.725e+04   1.14e+04     -4.149      0.000   -6.96e+04   -2.49e+04
# ...

# %%
data2  =hd.copy()
dummy_variables = pd.get_dummies(data2.OCCUPANCY,prefix = "OCC")

# %%
dummy_variables
# Out:
#       OCC_1.0  OCC_2.0  OCC_3.0
# 0           1        0        0
# 1           0        1        0
# 2           1        0        0
# 3           1        0        0
# 4           0        1        0
# ...       ...      ...      ...
# 1075        1        0        0
# 1076        0        1        0
# 1077        0        1        0
# 1078        1        0        0
# 1079        1        0        0
#
# [1080 rows x 3 columns]

# %%
hd1=pd.concat([hd,dummy_variables],axis = 1)

# %%
hd1
# Out:
#           PRICE    SQFT  BEDROOMS  BATHS   AGE  OCCUPANCY  POOL  STYLE  \
# 0       66500.0   741.0       1.0    1.0  18.0        1.0   1.0    1.0
# 1       66000.0   741.0       1.0    1.0  18.0        2.0   1.0    1.0
# 2       68500.0   790.0       1.0    1.0  18.0        1.0   0.0    1.0
# 3      102000.0  2783.0       2.0    2.0  18.0        1.0   0.0    1.0
# 4       54000.0  1165.0       2.0    1.0  35.0        2.0   0.0    1.0
# ...         ...     ...       ...    ...   ...        ...   ...    ...
# 1075   122570.0  2853.0       5.0    3.0  25.0        1.0   0.0   11.0
# 1076   185000.0  4599.0       5.0    3.0  13.0        2.0   1.0   11.0
# 1077  1280000.0  7086.0       5.0    3.0  13.0        2.0   1.0   11.0
# 1078   123808.0  3148.0       5.0    2.0  25.0        1.0   0.0   11.0
# 1079   374000.0  6203.0       7.0    4.0  25.0        1.0   1.0   11.0
#
#       FIREPLACE  WATERFRONT    DOM  OCC_1.0  OCC_2.0  OCC_3.0
# ...

# %%
y = hd1['PRICE']
x = hd1[['SQFT', 'BEDROOMS', 'BATHS','POOL', 'FIREPLACE', 'WATERFRONT', 'OCC_1.0', 'OCC_3.0']]

# %%
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     231.3
# Date:                Thu, 30 May 2024   Prob (F-statistic):          2.79e-227
# Time:                        10:59:01   Log-Likelihood:                -13647.
# No. Observations:                1080   AIC:                         2.731e+04
# Df Residuals:                    1071   BIC:                         2.736e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.066e+04    1.2e+04     -5.055      0.000   -8.42e+04   -3.71e+04
# ...
